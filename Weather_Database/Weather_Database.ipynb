# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests

# %%
# Create set of 2,000 latitudes and longitudes
lats = np.random.uniform(-90, 90, 2000)
lngs = np.random.uniform(-180, 180, 2000)
# Zip both lists and extract to a list of coordinates
coords = list(zip(lats,lngs))

# %%
# Initialize cities list
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coord in coords:
    city = citipy.nearest_city(coord[0], coord[1]).city_name
    country = citipy.nearest_city(coord[0], coord[1]).country_code
    
    # If the city is unique, then we will add it to the cities list.
    if (city,country) not in cities:
        cities.append((city,country))

# %%
# Check the number of cities
len(cities)
# Out:
# 745

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | jalu
# Processing Record 2 of the Set 1 | atuona
# Processing Record 3 of the Set 1 | tiksi
# Processing Record 4 of the Set 1 | bluff
# Processing Record 5 of the Set 1 | kalabo
# Processing Record 6 of the Set 1 | vila franca do campo
# Processing Record 7 of the Set 1 | port alfred
# Processing Record 8 of the Set 1 | ushuaia
# Processing Record 9 of the Set 1 | tasiilaq
# Processing Record 10 of the Set 1 | lasa
# Processing Record 11 of the Set 1 | neiafu
# Processing Record 12 of the Set 1 | te anau
# Processing Record 13 of the Set 1 | yar-sale
# Processing Record 14 of the Set 1 | lorengau
# Processing Record 15 of the Set 1 | henties bay
# Processing Record 16 of the Set 1 | cidreira
# Processing Record 17 of the Set 1 | amderma
# Processing Record 18 of the Set 1 | yellowknife
# Processing Record 19 of the Set 1 | severo-kurilsk
# Processing Record 20 of the Set 1 | illoqqortoormiut
# Processing Record 21 of the Set 1 | bethel
# Processing Record 22 of the Set 1 | tongren
# Processing Record 23 of the Set 1 | vardo
# Processing Record 24 of the Set 1 | faya
# Processing Record 25 of the Set 1 | bredasdorp
# Processing Record 26 of the Set 1 | kurchum
# Processing Record 27 of the Set 1 | mount gambier
# Processing Record 28 of the Set 1 | busselton
# Processing Record 29 of the Set 1 | kefalos
# Processing Record 30 of the Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 31 of the Set 1 | fonte boa
# Processing Record 32 of the Set 1 | geraldton
# Processing Record 33 of the Set 1 | sorvag
# City not found. Skipping...
# Processing Record 34 of the Set 1 | hilo
# Processing Record 35 of the Set 1 | cayenne
# Processing Record 36 of the Set 1 | nizhneyansk
# Processing Record 37 of the Set 1 | albany
# Processing Record 38 of the Set 1 | makakilo city
# Processing Record 39 of the Set 1 | zhob
# Processing Record 40 of the Set 1 | kabalo
# Processing Record 41 of the Set 1 | carnarvon
# Processing Record 42 of the Set 1 | tsiroanomandidy
# Processing Record 43 of the Set 1 | saleaula
# City not found. Skipping...
# Processing Record 44 of the Set 1 | tuktoyaktuk
# Processing Record 45 of the Set 1 | nanortalik
# Processing Record 46 of the Set 1 | ostrovnoy
# Processing Record 47 of the Set 1 | chokurdakh
# Processing Record 48 of the Set 1 | beyneu
# Processing Record 49 of the Set 1 | khatanga
# Processing Record 50 of the Set 1 | nabire
# Processing Record 1 of the Set 2 | mataura
# Processing Record 2 of the Set 2 | champerico
# Processing Record 3 of the Set 2 | clyde river
# Processing Record 4 of the Set 2 | tabou
# Processing Record 5 of the Set 2 | half moon bay
# Processing Record 6 of the Set 2 | jamestown
# Processing Record 7 of the Set 2 | cape town
# Processing Record 8 of the Set 2 | egvekinot
# Processing Record 9 of the Set 2 | taolanaro
# Processing Record 10 of the Set 2 | batagay
# Processing Record 11 of the Set 2 | kapaa
# Processing Record 12 of the Set 2 | mareeba
# Processing Record 13 of the Set 2 | karratha
# Processing Record 14 of the Set 2 | hobart
# Processing Record 15 of the Set 2 | trincomalee
# Processing Record 16 of the Set 2 | vila do maio
# Processing Record 17 of the Set 2 | umm kaddadah
# Processing Record 18 of the Set 2 | meadow lake
# Processing Record 19 of the Set 2 | kavaratti
# Processing Record 20 of the Set 2 | turan
# Processing Record 21 of the Set 2 | teseney
# Processing Record 22 of the Set 2 | barbar
# Processing Record 23 of the Set 2 | brae
# Processing Record 24 of the Set 2 | kavieng
# Processing Record 25 of the Set 2 | meulaboh
# Processing Record 26 of the Set 2 | georgetown
# Processing Record 27 of the Set 2 | imbituba
# Processing Record 28 of the Set 2 | saskylakh
# Processing Record 29 of the Set 2 | camaqua
# Processing Record 30 of the Set 2 | nikolskoye
# Processing Record 31 of the Set 2 | hermanus
# Processing Record 32 of the Set 2 | klaksvik
# City not found. Skipping...
# Processing Record 33 of the Set 2 | tilichiki
# Processing Record 34 of the Set 2 | caraballeda
# Processing Record 35 of the Set 2 | dikson
# Processing Record 36 of the Set 2 | leningradskiy
# Processing Record 37 of the Set 2 | vaini
# Processing Record 38 of the Set 2 | fairmont
# Processing Record 39 of the Set 2 | san quintin
# Processing Record 40 of the Set 2 | labuhan
# Processing Record 41 of the Set 2 | banjar
# Processing Record 42 of the Set 2 | kathmandu
# Processing Record 43 of the Set 2 | skalistyy
# Processing Record 44 of the Set 2 | san patricio
# Processing Record 45 of the Set 2 | katsuura
# Processing Record 46 of the Set 2 | majene
# Processing Record 47 of the Set 2 | punta arenas
# Processing Record 48 of the Set 2 | almaty
# Processing Record 49 of the Set 2 | hithadhoo
# Processing Record 50 of the Set 2 | laguna
# Processing Record 1 of the Set 3 | nemuro
# Processing Record 2 of the Set 3 | diffa
# Processing Record 3 of the Set 3 | sola
# Processing Record 4 of the Set 3 | broome
# Processing Record 5 of the Set 3 | kenora
# Processing Record 6 of the Set 3 | ribeira grande
# Processing Record 7 of the Set 3 | menongue
# Processing Record 8 of the Set 3 | camacha
# Processing Record 9 of the Set 3 | nokaneng
# Processing Record 10 of the Set 3 | uyuni
# Processing Record 11 of the Set 3 | itoman
# Processing Record 12 of the Set 3 | new norfolk
# Processing Record 13 of the Set 3 | touros
# Processing Record 14 of the Set 3 | tumannyy
# Processing Record 15 of the Set 3 | gazojak
# Processing Record 16 of the Set 3 | westport
# Processing Record 17 of the Set 3 | vanimo
# Processing Record 18 of the Set 3 | butaritari
# Processing Record 19 of the Set 3 | danville
# Processing Record 20 of the Set 3 | jumla
# Processing Record 21 of the Set 3 | ponta do sol
# Processing Record 22 of the Set 3 | finschhafen
# Processing Record 23 of the Set 3 | pokrovsk
# Processing Record 24 of the Set 3 | kloulklubed
# Processing Record 25 of the Set 3 | isangel
# Processing Record 26 of the Set 3 | qibili
# City not found. Skipping...
# Processing Record 27 of the Set 3 | luanda
# Processing Record 28 of the Set 3 | burnie
# Processing Record 29 of the Set 3 | salinopolis
# Processing Record 30 of the Set 3 | puerto ayora
# Processing Record 31 of the Set 3 | mar del plata
# Processing Record 32 of the Set 3 | bonavista
# Processing Record 33 of the Set 3 | rikitea
# Processing Record 34 of the Set 3 | ruatoria
# Processing Record 35 of the Set 3 | samusu
# City not found. Skipping...
# Processing Record 36 of the Set 3 | talant
# Processing Record 37 of the Set 3 | corni
# Processing Record 38 of the Set 3 | stokmarknes
# Processing Record 39 of the Set 3 | san julian
# Processing Record 40 of the Set 3 | kanigoro
# Processing Record 41 of the Set 3 | comodoro rivadavia
# Processing Record 42 of the Set 3 | rubtsovsk
# Processing Record 43 of the Set 3 | victoria
# Processing Record 44 of the Set 3 | fare
# Processing Record 45 of the Set 3 | mys shmidta
# Processing Record 46 of the Set 3 | davila
# Processing Record 47 of the Set 3 | ayotzintepec
# Processing Record 48 of the Set 3 | kati
# Processing Record 49 of the Set 3 | kodiak
# Processing Record 50 of the Set 3 | alofi
# Processing Record 1 of the Set 4 | colares
# Processing Record 2 of the Set 4 | lima
# Processing Record 3 of the Set 4 | muros
# Processing Record 4 of the Set 4 | eureka
# Processing Record 5 of the Set 4 | milingimbi
# Processing Record 6 of the Set 4 | kalakamati
# Processing Record 7 of the Set 4 | sao felix do xingu
# Processing Record 8 of the Set 4 | sohag
# Processing Record 9 of the Set 4 | lebu
# Processing Record 10 of the Set 4 | luganville
# Processing Record 11 of the Set 4 | nelson bay
# Processing Record 12 of the Set 4 | opuwo
# Processing Record 13 of the Set 4 | brighton
# Processing Record 14 of the Set 4 | sechura
# Processing Record 15 of the Set 4 | gat
# Processing Record 16 of the Set 4 | byron bay
# Processing Record 17 of the Set 4 | hualmay
# Processing Record 18 of the Set 4 | roald
# Processing Record 19 of the Set 4 | kaduna
# Processing Record 20 of the Set 4 | sitka
# Processing Record 21 of the Set 4 | muli
# Processing Record 22 of the Set 4 | storslett
# Processing Record 23 of the Set 4 | gamba
# Processing Record 24 of the Set 4 | general roca
# Processing Record 25 of the Set 4 | cheremushskiy
# Processing Record 26 of the Set 4 | hamilton
# Processing Record 27 of the Set 4 | tamandare
# Processing Record 28 of the Set 4 | mzimba
# Processing Record 29 of the Set 4 | illapel
# Processing Record 30 of the Set 4 | baykit
# Processing Record 31 of the Set 4 | souillac
# Processing Record 32 of the Set 4 | odesskoye
# Processing Record 33 of the Set 4 | gao
# Processing Record 34 of the Set 4 | pitimbu
# Processing Record 35 of the Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 36 of the Set 4 | northam
# Processing Record 37 of the Set 4 | iraquara
# Processing Record 38 of the Set 4 | chuy
# Processing Record 39 of the Set 4 | matias romero
# Processing Record 40 of the Set 4 | nova aurora
# Processing Record 41 of the Set 4 | elbistan
# Processing Record 42 of the Set 4 | la joya
# Processing Record 43 of the Set 4 | sao filipe
# Processing Record 44 of the Set 4 | portland
# Processing Record 45 of the Set 4 | la cruz
# Processing Record 46 of the Set 4 | srednekolymsk
# Processing Record 47 of the Set 4 | balkhash
# Processing Record 48 of the Set 4 | norman wells
# Processing Record 49 of the Set 4 | amahai
# Processing Record 50 of the Set 4 | macon
# Processing Record 1 of the Set 5 | belushya guba
# Processing Record 2 of the Set 5 | naryan-mar
# Processing Record 3 of the Set 5 | port elizabeth
# Processing Record 4 of the Set 5 | mehamn
# Processing Record 5 of the Set 5 | novorzhev
# Processing Record 6 of the Set 5 | skjervoy
# Processing Record 7 of the Set 5 | valjala
# City not found. Skipping...
# Processing Record 8 of the Set 5 | tevaitoa
# Processing Record 9 of the Set 5 | luderitz
# Processing Record 10 of the Set 5 | oyon
# Processing Record 11 of the Set 5 | arraial do cabo
# Processing Record 12 of the Set 5 | pirkkala
# Processing Record 13 of the Set 5 | dali
# Processing Record 14 of the Set 5 | kristiinankaupunki
# Processing Record 15 of the Set 5 | srikakulam
# Processing Record 16 of the Set 5 | sakakah
# Processing Record 17 of the Set 5 | svay rieng
# Processing Record 18 of the Set 5 | tiznit
# Processing Record 19 of the Set 5 | bambous virieux
# Processing Record 20 of the Set 5 | airai
# Processing Record 21 of the Set 5 | ilulissat
# Processing Record 22 of the Set 5 | rafraf
# City not found. Skipping...
# Processing Record 23 of the Set 5 | bowen
# Processing Record 24 of the Set 5 | vanavara
# Processing Record 25 of the Set 5 | saint-francois
# Processing Record 26 of the Set 5 | adrar
# Processing Record 27 of the Set 5 | provideniya
# Processing Record 28 of the Set 5 | ngunguru
# Processing Record 29 of the Set 5 | phonhong
# Processing Record 30 of the Set 5 | kieta
# Processing Record 31 of the Set 5 | tarko-sale
# Processing Record 32 of the Set 5 | avarua
# Processing Record 33 of the Set 5 | saint-pierre
# Processing Record 34 of the Set 5 | kurumkan
# Processing Record 35 of the Set 5 | tiarei
# Processing Record 36 of the Set 5 | buraydah
# Processing Record 37 of the Set 5 | saint-augustin
# Processing Record 38 of the Set 5 | port lincoln
# Processing Record 39 of the Set 5 | bayevo
# Processing Record 40 of the Set 5 | henderson
# Processing Record 41 of the Set 5 | kutum
# Processing Record 42 of the Set 5 | kachikau
# Processing Record 43 of the Set 5 | teruel
# Processing Record 44 of the Set 5 | georgiyevka
# Processing Record 45 of the Set 5 | male
# Processing Record 46 of the Set 5 | qaanaaq
# Processing Record 47 of the Set 5 | da nang
# Processing Record 48 of the Set 5 | emerald
# Processing Record 49 of the Set 5 | ketchikan
# Processing Record 50 of the Set 5 | saldanha
# Processing Record 1 of the Set 6 | sangar
# Processing Record 2 of the Set 6 | ancud
# Processing Record 3 of the Set 6 | asyut
# Processing Record 4 of the Set 6 | itarema
# Processing Record 5 of the Set 6 | ixtapa
# Processing Record 6 of the Set 6 | elat
# Processing Record 7 of the Set 6 | galle
# Processing Record 8 of the Set 6 | castro
# Processing Record 9 of the Set 6 | saint anthony
# Processing Record 10 of the Set 6 | aklavik
# Processing Record 11 of the Set 6 | sabha
# Processing Record 12 of the Set 6 | saint-philippe
# Processing Record 13 of the Set 6 | alamosa
# Processing Record 14 of the Set 6 | naze
# Processing Record 15 of the Set 6 | bathsheba
# Processing Record 16 of the Set 6 | zmeinogorsk
# Processing Record 17 of the Set 6 | jabiru
# Processing Record 18 of the Set 6 | spearfish
# Processing Record 19 of the Set 6 | ardistan
# City not found. Skipping...
# Processing Record 20 of the Set 6 | padang
# Processing Record 21 of the Set 6 | barrow
# Processing Record 22 of the Set 6 | bengkulu
# Processing Record 23 of the Set 6 | misratah
# Processing Record 24 of the Set 6 | san vicente
# Processing Record 25 of the Set 6 | seoul
# Processing Record 26 of the Set 6 | richards bay
# Processing Record 27 of the Set 6 | dalbandin
# Processing Record 28 of the Set 6 | topeka
# Processing Record 29 of the Set 6 | copiapo
# Processing Record 30 of the Set 6 | torbay
# Processing Record 31 of the Set 6 | pevek
# Processing Record 32 of the Set 6 | dmitrovsk-orlovskiy
# Processing Record 33 of the Set 6 | beterou
# Processing Record 34 of the Set 6 | lompoc
# Processing Record 35 of the Set 6 | upernavik
# Processing Record 36 of the Set 6 | lagoa
# Processing Record 37 of the Set 6 | sisimiut
# Processing Record 38 of the Set 6 | anadyr
# Processing Record 39 of the Set 6 | viedma
# Processing Record 40 of the Set 6 | bonthe
# Processing Record 41 of the Set 6 | deputatskiy
# Processing Record 42 of the Set 6 | boyuibe
# Processing Record 43 of the Set 6 | wajima
# Processing Record 44 of the Set 6 | acapulco
# Processing Record 45 of the Set 6 | port-gentil
# Processing Record 46 of the Set 6 | lincoln
# Processing Record 47 of the Set 6 | caxito
# Processing Record 48 of the Set 6 | olinda
# Processing Record 49 of the Set 6 | otofuke
# Processing Record 50 of the Set 6 | uskedal
# Processing Record 1 of the Set 7 | east london
# Processing Record 2 of the Set 7 | bria
# Processing Record 3 of the Set 7 | faridan
# City not found. Skipping...
# Processing Record 4 of the Set 7 | esperance
# Processing Record 5 of the Set 7 | coahuayana
# Processing Record 6 of the Set 7 | shouguang
# Processing Record 7 of the Set 7 | jiayuguan
# Processing Record 8 of the Set 7 | caravelas
# Processing Record 9 of the Set 7 | oyama
# Processing Record 10 of the Set 7 | saint-georges
# Processing Record 11 of the Set 7 | lavrentiya
# Processing Record 12 of the Set 7 | neuquen
# Processing Record 13 of the Set 7 | pacific grove
# Processing Record 14 of the Set 7 | kodinsk
# Processing Record 15 of the Set 7 | la ronge
# Processing Record 16 of the Set 7 | kyaikto
# Processing Record 17 of the Set 7 | roma
# Processing Record 18 of the Set 7 | north creek
# Processing Record 19 of the Set 7 | fortuna
# Processing Record 20 of the Set 7 | cabo san lucas
# Processing Record 21 of the Set 7 | indramayu
# Processing Record 22 of the Set 7 | ardesen
# Processing Record 23 of the Set 7 | faanui
# Processing Record 24 of the Set 7 | veraval
# Processing Record 25 of the Set 7 | salvador
# Processing Record 26 of the Set 7 | port augusta
# Processing Record 27 of the Set 7 | attawapiskat
# Processing Record 28 of the Set 7 | constitucion
# Processing Record 29 of the Set 7 | salalah
# Processing Record 30 of the Set 7 | yerbogachen
# Processing Record 31 of the Set 7 | saravan
# Processing Record 32 of the Set 7 | kruisfontein
# Processing Record 33 of the Set 7 | raudeberg
# Processing Record 34 of the Set 7 | kahului
# Processing Record 35 of the Set 7 | igarka
# Processing Record 36 of the Set 7 | hambantota
# Processing Record 37 of the Set 7 | ponta do sol
# Processing Record 38 of the Set 7 | watrous
# Processing Record 39 of the Set 7 | chernigovka
# Processing Record 40 of the Set 7 | poum
# Processing Record 41 of the Set 7 | aranda de duero
# Processing Record 42 of the Set 7 | narsaq
# Processing Record 43 of the Set 7 | okhotsk
# Processing Record 44 of the Set 7 | sentyabrskiy
# Processing Record 45 of the Set 7 | oussouye
# Processing Record 46 of the Set 7 | ciudad bolivar
# Processing Record 47 of the Set 7 | valdivia
# Processing Record 48 of the Set 7 | umm lajj
# Processing Record 49 of the Set 7 | bida
# Processing Record 50 of the Set 7 | port hardy
# Processing Record 1 of the Set 8 | chifeng
# Processing Record 2 of the Set 8 | santa cruz
# Processing Record 3 of the Set 8 | manta
# Processing Record 4 of the Set 8 | gornopravdinsk
# Processing Record 5 of the Set 8 | mahebourg
# Processing Record 6 of the Set 8 | gimli
# Processing Record 7 of the Set 8 | grand river south east
# Processing Record 8 of the Set 8 | cherskiy
# Processing Record 9 of the Set 8 | zhanaozen
# Processing Record 10 of the Set 8 | safaga
# Processing Record 11 of the Set 8 | shingu
# Processing Record 12 of the Set 8 | mormugao
# Processing Record 13 of the Set 8 | skibbereen
# Processing Record 14 of the Set 8 | wanaka
# Processing Record 15 of the Set 8 | aykhal
# Processing Record 16 of the Set 8 | ocean springs
# Processing Record 17 of the Set 8 | lerwick
# Processing Record 18 of the Set 8 | vadso
# Processing Record 19 of the Set 8 | husavik
# Processing Record 20 of the Set 8 | atar
# Processing Record 21 of the Set 8 | villa corzo
# Processing Record 22 of the Set 8 | visby
# Processing Record 23 of the Set 8 | palkaka
# City not found. Skipping...
# Processing Record 24 of the Set 8 | codrington
# Processing Record 25 of the Set 8 | alekseyevsk
# Processing Record 26 of the Set 8 | kolo
# Processing Record 27 of the Set 8 | alta gracia
# Processing Record 28 of the Set 8 | turtkul
# City not found. Skipping...
# Processing Record 29 of the Set 8 | hasaki
# Processing Record 30 of the Set 8 | saint george
# Processing Record 31 of the Set 8 | salta
# Processing Record 32 of the Set 8 | ransang
# Processing Record 33 of the Set 8 | royan
# Processing Record 34 of the Set 8 | assiniboia
# Processing Record 35 of the Set 8 | phibun mangsahan
# Processing Record 36 of the Set 8 | tando ghulam ali
# Processing Record 37 of the Set 8 | kuragino
# Processing Record 38 of the Set 8 | sobolevo
# Processing Record 39 of the Set 8 | sovetskaya gavan
# Processing Record 40 of the Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 41 of the Set 8 | los llanos de aridane
# Processing Record 42 of the Set 8 | san cristobal
# Processing Record 43 of the Set 8 | dukat
# Processing Record 44 of the Set 8 | carutapera
# Processing Record 45 of the Set 8 | villarrica
# Processing Record 46 of the Set 8 | shibetsu
# Processing Record 47 of the Set 8 | turukhansk
# Processing Record 48 of the Set 8 | flinders
# Processing Record 49 of the Set 8 | atbasar
# Processing Record 50 of the Set 8 | veracruz
# Processing Record 1 of the Set 9 | tatarskaya kargala
# Processing Record 2 of the Set 9 | hoopstad
# Processing Record 3 of the Set 9 | timmins
# Processing Record 4 of the Set 9 | buala
# Processing Record 5 of the Set 9 | manbij
# Processing Record 6 of the Set 9 | talnakh
# Processing Record 7 of the Set 9 | birjand
# City not found. Skipping...
# Processing Record 8 of the Set 9 | alugan
# Processing Record 9 of the Set 9 | curumani
# Processing Record 10 of the Set 9 | tsihombe
# Processing Record 11 of the Set 9 | kiruna
# Processing Record 12 of the Set 9 | paamiut
# Processing Record 13 of the Set 9 | esna
# Processing Record 14 of the Set 9 | cap malheureux
# Processing Record 15 of the Set 9 | almansa
# Processing Record 16 of the Set 9 | kantemirovka
# Processing Record 17 of the Set 9 | van
# Processing Record 18 of the Set 9 | longyearbyen
# City not found. Skipping...
# Processing Record 19 of the Set 9 | ust-uda
# Processing Record 20 of the Set 9 | rocha
# Processing Record 21 of the Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 22 of the Set 9 | maragogi
# Processing Record 23 of the Set 9 | cockburn town
# Processing Record 24 of the Set 9 | moses lake
# Processing Record 25 of the Set 9 | ijaki
# Processing Record 26 of the Set 9 | ewo
# Processing Record 27 of the Set 9 | coquimbo
# Processing Record 28 of the Set 9 | the valley
# Processing Record 29 of the Set 9 | muravlenko
# Processing Record 30 of the Set 9 | dawei
# Processing Record 31 of the Set 9 | akdepe
# Processing Record 32 of the Set 9 | pangnirtung
# Processing Record 33 of the Set 9 | tashtagol
# Processing Record 34 of the Set 9 | kenai
# Processing Record 35 of the Set 9 | sawtell
# Processing Record 36 of the Set 9 | mayor pablo lagerenza
# Processing Record 37 of the Set 9 | jizan
# Processing Record 38 of the Set 9 | mgandu
# Processing Record 39 of the Set 9 | nguiu
# Processing Record 40 of the Set 9 | hobyo
# City not found. Skipping...
# Processing Record 41 of the Set 9 | poronaysk
# Processing Record 42 of the Set 9 | koumac
# Processing Record 43 of the Set 9 | haradok
# Processing Record 44 of the Set 9 | shache
# Processing Record 45 of the Set 9 | malakal
# Processing Record 46 of the Set 9 | ust-ishim
# Processing Record 47 of the Set 9 | jutai
# Processing Record 48 of the Set 9 | galich
# Processing Record 49 of the Set 9 | beringovskiy
# Processing Record 50 of the Set 9 | gravina in puglia
# Processing Record 1 of the Set 10 | sovetskiy
# Processing Record 2 of the Set 10 | okulovka
# Processing Record 3 of the Set 10 | sept-iles
# Processing Record 4 of the Set 10 | sur
# Processing Record 5 of the Set 10 | prince rupert
# Processing Record 6 of the Set 10 | berdigestyakh
# Processing Record 7 of the Set 10 | antofagasta
# Processing Record 8 of the Set 10 | porbandar
# Processing Record 9 of the Set 10 | lokosovo
# Processing Record 10 of the Set 10 | inhambane
# Processing Record 11 of the Set 10 | qaqortoq
# Processing Record 12 of the Set 10 | straumen
# Processing Record 13 of the Set 10 | sassandra
# Processing Record 14 of the Set 10 | tomatlan
# Processing Record 15 of the Set 10 | barra patuca
# City not found. Skipping...
# Processing Record 16 of the Set 10 | kijang
# Processing Record 17 of the Set 10 | botshabelo
# Processing Record 18 of the Set 10 | bintulu
# Processing Record 19 of the Set 10 | mohanur
# Processing Record 20 of the Set 10 | sarakhs
# City not found. Skipping...
# Processing Record 21 of the Set 10 | jackson
# Processing Record 22 of the Set 10 | savalou
# Processing Record 23 of the Set 10 | tamiahua
# Processing Record 24 of the Set 10 | vallenar
# Processing Record 25 of the Set 10 | shieli
# Processing Record 26 of the Set 10 | umzimvubu
# Processing Record 27 of the Set 10 | acuna
# Processing Record 28 of the Set 10 | mesyagutovo
# Processing Record 29 of the Set 10 | bandarbeyla
# City not found. Skipping...
# Processing Record 30 of the Set 10 | komsomolskiy
# Processing Record 31 of the Set 10 | nome
# Processing Record 32 of the Set 10 | sao joao da barra
# Processing Record 33 of the Set 10 | nantucket
# Processing Record 34 of the Set 10 | huilong
# Processing Record 35 of the Set 10 | ballina
# Processing Record 36 of the Set 10 | marawi
# Processing Record 37 of the Set 10 | olafsvik
# Processing Record 38 of the Set 10 | makinsk
# Processing Record 39 of the Set 10 | healdsburg
# Processing Record 40 of the Set 10 | basi
# Processing Record 41 of the Set 10 | three hills
# Processing Record 42 of the Set 10 | clinton
# Processing Record 43 of the Set 10 | felidhoo
# Processing Record 44 of the Set 10 | belmonte
# Processing Record 45 of the Set 10 | bela
# Processing Record 46 of the Set 10 | kuopio
# Processing Record 47 of the Set 10 | niamey
# Processing Record 48 of the Set 10 | antalaha
# Processing Record 49 of the Set 10 | plettenberg bay
# Processing Record 50 of the Set 10 | ingham
# Processing Record 1 of the Set 11 | jiangyou
# Processing Record 2 of the Set 11 | basco
# Processing Record 3 of the Set 11 | makasar
# Processing Record 4 of the Set 11 | thompson
# Processing Record 5 of the Set 11 | barcelona
# Processing Record 6 of the Set 11 | quatre cocos
# Processing Record 7 of the Set 11 | regina
# Processing Record 8 of the Set 11 | broken hill
# Processing Record 9 of the Set 11 | karkaralinsk
# Processing Record 10 of the Set 11 | pella
# Processing Record 11 of the Set 11 | devils lake
# Processing Record 12 of the Set 11 | chiang klang
# Processing Record 13 of the Set 11 | ambilobe
# Processing Record 14 of the Set 11 | pathalgaon
# Processing Record 15 of the Set 11 | vao
# Processing Record 16 of the Set 11 | taoudenni
# Processing Record 17 of the Set 11 | saint-felicien
# Processing Record 18 of the Set 11 | huarmey
# Processing Record 19 of the Set 11 | chikwawa
# Processing Record 20 of the Set 11 | porto novo
# Processing Record 21 of the Set 11 | agadir
# Processing Record 22 of the Set 11 | ordu
# Processing Record 23 of the Set 11 | pascagoula
# Processing Record 24 of the Set 11 | madisonville
# Processing Record 25 of the Set 11 | blythe
# Processing Record 26 of the Set 11 | tucuma
# Processing Record 27 of the Set 11 | kasongo-lunda
# Processing Record 28 of the Set 11 | macau
# Processing Record 29 of the Set 11 | fairbanks
# Processing Record 30 of the Set 11 | arandis
# Processing Record 31 of the Set 11 | ozernovskiy
# Processing Record 32 of the Set 11 | dunedin
# Processing Record 33 of the Set 11 | horsham
# Processing Record 34 of the Set 11 | ostrov
# Processing Record 35 of the Set 11 | pontes e lacerda
# Processing Record 36 of the Set 11 | nkhotakota
# Processing Record 37 of the Set 11 | jilin
# Processing Record 38 of the Set 11 | grafton
# Processing Record 39 of the Set 11 | toluviejo
# Processing Record 40 of the Set 11 | aswan
# Processing Record 41 of the Set 11 | vostok
# Processing Record 42 of the Set 11 | minab
# City not found. Skipping...
# Processing Record 43 of the Set 11 | havre-saint-pierre
# Processing Record 44 of the Set 11 | pangai
# Processing Record 45 of the Set 11 | kolpashevo
# Processing Record 46 of the Set 11 | preston
# Processing Record 47 of the Set 11 | pisco
# Processing Record 48 of the Set 11 | asfi
# Processing Record 49 of the Set 11 | la rioja
# Processing Record 50 of the Set 11 | kununurra
# Processing Record 1 of the Set 12 | bambanglipuro
# Processing Record 2 of the Set 12 | yenagoa
# Processing Record 3 of the Set 12 | westport
# Processing Record 4 of the Set 12 | port hedland
# Processing Record 5 of the Set 12 | qasigiannguit
# Processing Record 6 of the Set 12 | namatanai
# Processing Record 7 of the Set 12 | dickinson
# Processing Record 8 of the Set 12 | port macquarie
# Processing Record 9 of the Set 12 | bolungarvik
# Processing Record 10 of the Set 12 | izalco
# Processing Record 11 of the Set 12 | gejiu
# Processing Record 12 of the Set 12 | kayunga
# Processing Record 13 of the Set 12 | dakar
# Processing Record 14 of the Set 12 | aanekoski
# Processing Record 15 of the Set 12 | sol-iletsk
# Processing Record 16 of the Set 12 | zambezi
# Processing Record 17 of the Set 12 | djambala
# Processing Record 18 of the Set 12 | coolum beach
# Processing Record 19 of the Set 12 | biloela
# Processing Record 20 of the Set 12 | ossora
# Processing Record 21 of the Set 12 | beibei
# Processing Record 22 of the Set 12 | san mauro torinese
# Processing Record 23 of the Set 12 | burns lake
# Processing Record 24 of the Set 12 | kaitangata
# Processing Record 25 of the Set 12 | revelstoke
# Processing Record 26 of the Set 12 | ust-tsilma
# Processing Record 27 of the Set 12 | hofn
# Processing Record 28 of the Set 12 | berezovyy
# Processing Record 29 of the Set 12 | verkhoyansk
# Processing Record 30 of the Set 12 | derzhavinsk
# Processing Record 31 of the Set 12 | braedstrup
# Processing Record 32 of the Set 12 | joensuu
# Processing Record 33 of the Set 12 | tallahassee
# Processing Record 34 of the Set 12 | santa maria da vitoria
# Processing Record 35 of the Set 12 | novyye lyady
# Processing Record 36 of the Set 12 | bolshoye selo
# Processing Record 37 of the Set 12 | vestmanna
# Processing Record 38 of the Set 12 | bargal
# City not found. Skipping...
# Processing Record 39 of the Set 12 | tshela
# Processing Record 40 of the Set 12 | vincennes
# Processing Record 41 of the Set 12 | qalyub
# Processing Record 42 of the Set 12 | villazon
# Processing Record 43 of the Set 12 | alcantara
# Processing Record 44 of the Set 12 | chumphon
# Processing Record 45 of the Set 12 | talaya
# Processing Record 46 of the Set 12 | marfino
# Processing Record 47 of the Set 12 | otuzco
# Processing Record 48 of the Set 12 | mazamari
# Processing Record 49 of the Set 12 | macaboboni
# Processing Record 50 of the Set 12 | freeport
# Processing Record 1 of the Set 13 | oster
# Processing Record 2 of the Set 13 | ostrovskoye
# Processing Record 3 of the Set 13 | iquique
# Processing Record 4 of the Set 13 | guerrero negro
# Processing Record 5 of the Set 13 | sayyan
# Processing Record 6 of the Set 13 | praia da vitoria
# Processing Record 7 of the Set 13 | komatipoort
# Processing Record 8 of the Set 13 | kunzelsau
# Processing Record 9 of the Set 13 | belle fourche
# Processing Record 10 of the Set 13 | venado tuerto
# Processing Record 11 of the Set 13 | urzhum
# Processing Record 12 of the Set 13 | kazalinsk
# Processing Record 13 of the Set 13 | yirol
# Processing Record 14 of the Set 13 | denpasar
# Processing Record 15 of the Set 13 | alice springs
# Processing Record 16 of the Set 13 | marystown
# Processing Record 17 of the Set 13 | vestmannaeyjar
# Processing Record 18 of the Set 13 | mayo
# Processing Record 19 of the Set 13 | tuy hoa
# Processing Record 20 of the Set 13 | victor harbor
# Processing Record 21 of the Set 13 | chagda
# Processing Record 22 of the Set 13 | khonuu
# Processing Record 23 of the Set 13 | ahipara
# Processing Record 24 of the Set 13 | khandyga
# Processing Record 25 of the Set 13 | waingapu
# Processing Record 26 of the Set 13 | asau
# Processing Record 27 of the Set 13 | valparaiso
# Processing Record 28 of the Set 13 | hebi
# Processing Record 29 of the Set 13 | suluq
# Processing Record 30 of the Set 13 | floro
# Processing Record 31 of the Set 13 | marcona
# Processing Record 32 of the Set 13 | marsh harbour
# Processing Record 33 of the Set 13 | beaverlodge
# Processing Record 34 of the Set 13 | vicuna
# Processing Record 35 of the Set 13 | khuzhir
# Processing Record 36 of the Set 13 | banmo
# Processing Record 37 of the Set 13 | sao jose do rio pardo
# Processing Record 38 of the Set 13 | ebolowa
# Processing Record 39 of the Set 13 | rusape
# Processing Record 40 of the Set 13 | concordia
# Processing Record 41 of the Set 13 | zhuozhou
# Processing Record 42 of the Set 13 | bose
# Processing Record 43 of the Set 13 | sharjah
# Processing Record 44 of the Set 13 | serov
# Processing Record 45 of the Set 13 | sao desiderio
# Processing Record 46 of the Set 13 | surgut
# Processing Record 47 of the Set 13 | vila velha
# Processing Record 48 of the Set 13 | hagere selam
# Processing Record 49 of the Set 13 | niesky
# Processing Record 50 of the Set 13 | shizunai
# Processing Record 1 of the Set 14 | yatou
# Processing Record 2 of the Set 14 | aitape
# Processing Record 3 of the Set 14 | havelock
# Processing Record 4 of the Set 14 | ushtobe
# Processing Record 5 of the Set 14 | hervey bay
# Processing Record 6 of the Set 14 | lethem
# Processing Record 7 of the Set 14 | abashiri
# Processing Record 8 of the Set 14 | petropavlovsk-kamchatskiy
# Processing Record 9 of the Set 14 | mana
# Processing Record 10 of the Set 14 | tombouctou
# Processing Record 11 of the Set 14 | georgiyevskoye
# Processing Record 12 of the Set 14 | gogrial
# Processing Record 13 of the Set 14 | hukuntsi
# Processing Record 14 of the Set 14 | arona
# Processing Record 15 of the Set 14 | weinan
# Processing Record 16 of the Set 14 | haines junction
# Processing Record 17 of the Set 14 | sandy bay
# City not found. Skipping...
# Processing Record 18 of the Set 14 | merauke
# Processing Record 19 of the Set 14 | ribeira brava
# Processing Record 20 of the Set 14 | rio gallegos
# Processing Record 21 of the Set 14 | newcastle
# Processing Record 22 of the Set 14 | dzilam gonzalez
# Processing Record 23 of the Set 14 | horki
# Processing Record 24 of the Set 14 | aksu
# Processing Record 25 of the Set 14 | ariquemes
# Processing Record 26 of the Set 14 | atherton
# Processing Record 27 of the Set 14 | kimbe
# Processing Record 28 of the Set 14 | shahrud
# City not found. Skipping...
# Processing Record 29 of the Set 14 | fort-shevchenko
# Processing Record 30 of the Set 14 | yuzhou
# Processing Record 31 of the Set 14 | ozgon
# City not found. Skipping...
# Processing Record 32 of the Set 14 | tottori
# Processing Record 33 of the Set 14 | algiers
# Processing Record 34 of the Set 14 | kirakira
# Processing Record 35 of the Set 14 | tanshui
# City not found. Skipping...
# Processing Record 36 of the Set 14 | karabulak
# Processing Record 37 of the Set 14 | samandag
# Processing Record 38 of the Set 14 | tarauaca
# Processing Record 39 of the Set 14 | rio grande
# Processing Record 40 of the Set 14 | conner
# Processing Record 41 of the Set 14 | bilibino
# Processing Record 42 of the Set 14 | balkanabat
# Processing Record 43 of the Set 14 | salamanca
# Processing Record 44 of the Set 14 | doctor pedro p. pena
# Processing Record 45 of the Set 14 | bocaiuva
# Processing Record 46 of the Set 14 | westpunt
# City not found. Skipping...
# Processing Record 47 of the Set 14 | el dorado
# Processing Record 48 of the Set 14 | tigil
# Processing Record 49 of the Set 14 | araouane
# Processing Record 50 of the Set 14 | matagami
# Processing Record 1 of the Set 15 | north bend
# Processing Record 2 of the Set 15 | itaituba
# Processing Record 3 of the Set 15 | belyy yar
# Processing Record 4 of the Set 15 | mount isa
# Processing Record 5 of the Set 15 | dibaya
# Processing Record 6 of the Set 15 | chiredzi
# Processing Record 7 of the Set 15 | nadym
# Processing Record 8 of the Set 15 | bagdarin
# Processing Record 9 of the Set 15 | maceio
# Processing Record 10 of the Set 15 | bure
# Processing Record 11 of the Set 15 | maraa
# Processing Record 12 of the Set 15 | grand-lahou
# Processing Record 13 of the Set 15 | fort nelson
# Processing Record 14 of the Set 15 | iqaluit
# Processing Record 15 of the Set 15 | grindavik
# Processing Record 16 of the Set 15 | yarada
# Processing Record 17 of the Set 15 | toulepleu
# Processing Record 18 of the Set 15 | mazagao
# Processing Record 19 of the Set 15 | lusambo
# Processing Record 20 of the Set 15 | tefe
# Processing Record 21 of the Set 15 | zitlala
# Processing Record 22 of the Set 15 | zaqatala
# Processing Record 23 of the Set 15 | fulitun
# Processing Record 24 of the Set 15 | port blair
# Processing Record 25 of the Set 15 | yeppoon
# Processing Record 26 of the Set 15 | burica
# City not found. Skipping...
# Processing Record 27 of the Set 15 | abalak
# Processing Record 28 of the Set 15 | jonkoping
# Processing Record 29 of the Set 15 | saint joseph
# Processing Record 30 of the Set 15 | sorland
# Processing Record 31 of the Set 15 | swan hill
# Processing Record 32 of the Set 15 | envira
# Processing Record 33 of the Set 15 | erzin
# Processing Record 34 of the Set 15 | severodvinsk
# Processing Record 35 of the Set 15 | imeni zhelyabova
# Processing Record 36 of the Set 15 | aden
# Processing Record 37 of the Set 15 | homer
# Processing Record 38 of the Set 15 | kalmunai
# Processing Record 39 of the Set 15 | muromtsevo
# Processing Record 40 of the Set 15 | miri
# Processing Record 41 of the Set 15 | pocatello
# Processing Record 42 of the Set 15 | caucaia
# Processing Record 43 of the Set 15 | yining
# Processing Record 44 of the Set 15 | aleksandrov gay
# Processing Record 45 of the Set 15 | senanga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Check numer of cities
len(city_data)
# Out:
# 716

# %%
# Add data to a new DataFrame
cities_weather_df = pd.DataFrame(city_data)
# Reorder the columns
cities_weather_df=cities_weather_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]]
cities_weather_df.head()
# Out:
#      City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Jalu      LY  29.0331   21.5482     66.24        58          97
# 1  Atuona      PF  -9.8000 -139.0333     79.90        77          12
# 2   Tiksi      RU  71.6872  128.8694     -7.92        99          77
# 3   Bluff      NZ -46.6000  168.3333     41.81        83           7
# 4  Kalabo      ZM -14.9700   22.6814     67.82        90          86
#
#    Wind Speed Current Description
# 0       16.40     overcast clouds
# 1       17.29          few clouds
# 2        2.04       broken clouds
# 3        8.25           clear sky
# 4        4.74          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the dataframe to csv
cities_weather_df.to_csv(output_data_file, index_label="City_ID")
